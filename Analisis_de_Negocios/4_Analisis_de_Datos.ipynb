# %% [markdown]
# | **Inicio** | **atrás 3** | **Siguiente 5** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./3_Recopilacion_y_Analisis_de_Requisitos.ipynb)| [⏩](./5_Comunicacion_Efectiva.ipynb)|

# %% [markdown]
# # **4. Análisis de Datos**

# %% [markdown]
# ## **Conceptos Básicos de Análisis de Datos**

# %% [markdown]
# ### **Uso de estadísticas descriptivas**

# %% [markdown]
# Las estadísticas descriptivas son una parte esencial del análisis de datos, ya que proporcionan un resumen compacto y comprensible de las características principales de un conjunto de datos. Vamos a explorar algunas de las estadísticas descriptivas más comunes y cómo se pueden utilizar con ejemplos y gráficos en código Python.
#
# **Estadísticas Descriptivas Comunes:**
#
# 1. **Media (Promedio):** La suma de todos los valores dividida por el número de elementos.
#
# 2. **Mediana:** El valor medio de un conjunto de datos cuando está ordenado.
#
# 3. **Desviación Estándar:** Una medida de la dispersión de los valores en un conjunto de datos.
#
# 4. **Percentiles:** El valor por debajo del cual cae un porcentaje dado de observaciones en un conjunto de datos.
#
# 5. **Boxplot (Diagrama de Caja):** Proporciona una representación visual de la mediana, los cuartiles y los valores atípicos.
#
# **Ejemplo en Python:**
#
# Vamos a generar un conjunto de datos ficticio y aplicar estas estadísticas descriptivas:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos aleatorios
np.random.seed(42)
data = np.random.normal(loc=0, scale=1, size=1000)

# Calcular estadísticas descriptivas
mean_value = np.mean(data)
median_value = np.median(data)
std_dev = np.std(data)
percentile_25 = np.percentile(data, 25)
percentile_75 = np.percentile(data, 75)

# Graficar un boxplot
plt.boxplot(data, vert=False)
plt.title('Boxplot del Conjunto de Datos')
plt.show()

# Imprimir las estadísticas
print(f'Media: {mean_value:.2f}')
print(f'Mediana: {median_value:.2f}')
print(f'Desviación Estándar: {std_dev:.2f}')
print(f'Percentil 25: {percentile_25:.2f}')
print(f'Percentil 75: {percentile_75:.2f}')
# Out:
# Media: 0.02
# Mediana: 0.03
# Desviación Estándar: 0.98
# Percentil 25: -0.65
# Percentil 75: 0.65

# %% [markdown]
# Este código genera un conjunto de datos normalmente distribuido, calcula estadísticas descriptivas y muestra un boxplot. Puedes adaptar este código según tus necesidades y aplicarlo a conjuntos de datos reales.
#
# Las estadísticas descriptivas te proporcionan una visión rápida de la tendencia central, la dispersión y la presencia de valores atípicos en tus datos. El boxplot es particularmente útil para visualizar estas características de manera concisa.

# %% [markdown]
# ### **Análisis exploratorio de datos**

# %% [markdown]
# El Análisis Exploratorio de Datos (EDA, por sus siglas en inglés) es una fase crucial en el proceso de análisis de datos. Su objetivo es comprender la estructura del conjunto de datos, identificar patrones, detectar valores atípicos y formular hipótesis para investigaciones adicionales. Vamos a explorar algunas técnicas comunes de EDA con ejemplos en Python.
#
# **Técnicas Comunes de EDA:**
#
# 1. **Histogramas y Gráficos de Densidad:**
#    - Proporcionan una visión de la distribución de los datos.
#
# 2. **Diagramas de dispersión:**
#    - Muestran la relación entre dos variables.
#
# 3. **Matriz de correlación:**
#    - Describe las relaciones lineales entre pares de variables.
#
# 4. **Diagrama de caja por categorías:**
#    - Permite comparar la distribución de una variable entre diferentes categorías.
#
# 5. **Gráficos de conteo:**
#    - Muestra la frecuencia de categorías en variables categóricas.
#
# 6. **Gráficos de violín:**
#    - Combinan información de boxplot y densidad.
#
# **Ejemplo en Python:**
#
# Vamos a utilizar un conjunto de datos de ejemplo y aplicar estas técnicas:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Histograma y Gráfico de Densidad
sns.histplot(tips['total_bill'], kde=True)
plt.title('Histograma y Gráfico de Densidad de Total Bill')
plt.show()

# Diagrama de Dispersión
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Diagrama de Dispersión entre Total Bill y Tip')
plt.show()

# Diagrama de Caja por Categorías
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Diagrama de Caja de Total Bill por Día')
plt.show()

# Gráfico de Violín
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Gráfico de Violín de Total Bill por Día')
plt.show()

# Gráfico de Conteo
sns.countplot(x='day', data=tips)
plt.title('Gráfico de Conteo de Días')
plt.show()

# %% [markdown]
# Estas visualizaciones te proporcionan información valiosa sobre la distribución de las variables, relaciones entre ellas y patrones específicos en tus datos. Puedes adaptar estas técnicas según la naturaleza de tu conjunto de datos y tus objetivos de análisis.

# %% [markdown]
# ## **Aplicación de Técnicas de Minería de Datos**

# %% [markdown]
# ### **Identificación de patrones y tendencias**

# %% [markdown]
# ### **Uso de algoritmos de clustering y clasificación**

# %% [markdown]
# La identificación de patrones y tendencias es una parte fundamental de la minería de datos. Puedes utilizar diversas técnicas y algoritmos para descubrir patrones en tus datos. A continuación, proporcionaré ejemplos utilizando Python y algunas de las bibliotecas más comunes como Pandas, Matplotlib y Scikit-Learn.
#
# **Identificación de Patrones con Análisis de Series Temporales**
#
# Supongamos que tienes datos de series temporales y deseas identificar patrones y tendencias a lo largo del tiempo. Utilizaremos un conjunto de datos simple de temperatura para este ejemplo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Crear un conjunto de datos de ejemplo de series temporales
fecha_inicio = '2022-01-01'
fecha_fin = '2022-12-31'
fechas = pd.date_range(start=fecha_inicio, end=fecha_fin)
num_dias = len(fechas)

# Generar temperaturas aleatorias para cada día
temperaturas = np.random.randint(20, 71, size=num_dias)

data = {'Fecha': fechas, 'Temperatura': temperaturas}
df = pd.DataFrame(data)

# Visualizar la serie temporal
plt.figure(figsize=(12, 6))
plt.plot(df['Fecha'], df['Temperatura'], marker='o')
plt.title('Temperatura a lo largo del tiempo')
plt.xlabel('Fecha')
plt.ylabel('Temperatura')
plt.grid(True)
plt.show()

# %% [markdown]
# Esta gráfica te dará una idea visual de cómo cambia la temperatura con el tiempo. Puedes identificar patrones estacionales, tendencias ascendentes o descendentes, etc.
#
# **Identificación de Patrones con Clustering**
#
# Supongamos que tienes un conjunto de datos multidimensional y deseas identificar grupos de patrones similares. Utilizaremos un conjunto de datos de iris y aplicaremos el algoritmo de K-Means para identificar patrones.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de iris
iris = load_iris()
X = iris.data

# Normalizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar K-Means con 3 clusters (puedes ajustar esto según tus necesidades)
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)
y_kmeans = kmeans.fit_predict(X_scaled)

# Personalizar la gráfica
plt.figure(figsize=(8, 6))  # Ajustar tamaño de la figura

# Scatter plot para los puntos de datos y los centros de los clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_kmeans, cmap='viridis', label='Datos')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centros de Cluster')

# Etiquetas y leyenda
plt.title('K-Means Clustering')
plt.xlabel('Característica 1 (Normalizada)')
plt.ylabel('Característica 2 (Normalizada)')
plt.legend()

# Añadir cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Esta gráfica muestra cómo K-Means agrupa los datos en clusters. Puedes ajustar el número de clusters y explorar patrones en diferentes dimensiones.
#
# Estos son solo ejemplos básicos, y la elección de técnicas específicas dependerá de tu conjunto de datos y tus objetivos. La minería de datos implica una exploración profunda y la aplicación de múltiples técnicas para descubrir patrones valiosos en tus datos.

# %% [markdown]
# | **Inicio** | **atrás 3** | **Siguiente 5** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./3_Recopilacion_y_Analisis_de_Requisitos.ipynb)| [⏩](./5_Comunicacion_Efectiva.ipynb)|
