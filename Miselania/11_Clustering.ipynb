# %% [markdown]
# | **Inicio** | **atrás 10** | **Siguiente 12** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./10_Plot_decision_tree.ipynb)| [⏩](./12_Naive_Baye.ipynb)|

# %% [markdown]
# # **11. Clustering**

# %% [markdown]
# ![clustering](../img/clustering.png "clustering")

# %% [markdown]
# El clustering (o agrupamiento) es una técnica en el campo del aprendizaje no supervisado que consiste en dividir un conjunto de datos en grupos o clústeres basados en la similitud entre los elementos. El objetivo principal es reunir objetos similares y separar aquellos que son diferentes. Esta técnica es ampliamente utilizada en diversos campos, como minería de datos, análisis de patrones, reconocimiento de patrones, entre otros.
#
# **Terminología:**
#
# 1. **Clúster:** Un grupo de objetos similares que comparten características comunes.
# 2. **Centroide:** El punto central de un clúster, que representa el centro de ese grupo.
# 3. **Similitud/Distancia:** Una medida que cuantifica la similitud o distancia entre dos puntos en función de ciertos atributos.
# 4. **Algoritmo de Clustering:** Un conjunto de reglas o procedimientos para dividir un conjunto de datos en clústeres.
#
# **Formula Matemática:**
#
# En el clustering, el concepto clave es la medida de similitud o distancia entre los puntos. Algunas medidas comunes incluyen la distancia euclidiana o la correlación. La fórmula general de la distancia euclidiana entre dos puntos $(p)$ y $(q)$ en un espacio bidimensional sería:
#
# $\text{Distancia Euclidiana}(p, q) = \sqrt{(q_1 - p_1)^2 + (q_2 - p_2)^2}$
#
# **Ejemplo con K-Means en Python:**
#
# Vamos a utilizar el algoritmo K-Means, uno de los algoritmos de clustering más populares, para agrupar datos de manera sencilla en Python:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Crear datos de ejemplo
X, _ = make_blobs(n_samples=300, centers=4, random_state=42, cluster_std=1.0)

# Aplicar K-Means con 4 clústeres
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)  # Establece el valor explícitamente
kmeans.fit(X)

# Obtener las etiquetas de los clústeres y los centroides
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Visualizar los clústeres y los centroides
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolors='k', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroides')
plt.title('Ejemplo de Clustering con K-Means')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.legend()
plt.show()

# %% [markdown]
# Este código utiliza K-Means para agrupar datos en 4 clústeres y luego visualiza los puntos de datos coloreados según sus asignaciones de clúster y marca los centroides de cada clúster en rojo.
#
# **Resumen:**
#
# El clustering es una herramienta poderosa para explorar y entender la estructura de datos no etiquetados. El K-Means es un ejemplo común, pero hay muchos otros algoritmos de clustering, y la elección del algoritmo depende del tipo de datos y el problema específico.

# %% [markdown]
# ### **Ejemplo**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Crear un conjunto de datos sintético con clusters
X, y = make_blobs(n_samples=300, centers=4, random_state=42)

# Crear un DataFrame
df = pd.DataFrame(data=X, columns=['Feature1', 'Feature2'])
df
# Out:
#       Feature1  Feature2
# 0    -9.297689  6.473679
# 1    -9.698741  6.938967
# 2    -1.686653  7.793442
# 3    -7.097308 -5.781333
# 4   -10.876452  6.315437
# ..         ...       ...
# 295  -3.660191  9.389984
# 296   3.810884  1.412989
# 297  -4.116681  9.198920
# 298  -8.819909  8.999960
# 299  -7.968722  8.679161
#
# [300 rows x 2 columns]

# %%
# Inicializar el modelo K-Means
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)

# Entrenar el modelo
kmeans.fit(X)

# Obtener las etiquetas de cluster y los centros
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Añadir las etiquetas de cluster al DataFrame
df['Cluster'] = labels

# Visualizar los datos y los clusters
plt.figure(figsize=(10, 6))

# Scatter plot para los datos coloreados por cluster
plt.scatter(df['Feature1'], df['Feature2'], c=df['Cluster'], cmap='viridis', edgecolors='k', s=50)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, label='Centroids')

plt.title('Clustering con K-Means')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.legend()
plt.show()

# %% [markdown]
# | **Inicio** | **atrás 10** | **Siguiente 12** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./10_Plot_decision_tree.ipynb)| [⏩](./12_Naive_Baye.ipynb)|
