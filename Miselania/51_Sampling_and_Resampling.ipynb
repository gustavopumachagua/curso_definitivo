# %% [markdown]
# | **Inicio** | **atrás 50** | **Siguiente 52** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./50_%20t-test.ipynb)| [⏩](./52_Central_Limit_Theorem.ipynb)|

# %% [markdown]
# # **51. Sampling & Resampling**

# %% [markdown]
# **Muestreo y Remuestreo: Explicación Detallada**
#
# **Muestreo:**
#
# En estadísticas, el muestreo se refiere al proceso de seleccionar un subconjunto de elementos de una población con el objetivo de realizar inferencias sobre toda la población. El muestreo es crucial cuando trabajar con grandes conjuntos de datos o cuando es impráctico o costoso analizar toda la población.
#
# **Terminología:**
#
# - **Población:** El conjunto completo de elementos o individuos que tienen una característica común y son el objeto de estudio.
#
# - **Muestra:** Un subconjunto representativo de la población que se selecciona para el análisis.
#
# - **Muestreo Aleatorio Simple:** Un método en el que cada individuo de la población tiene la misma probabilidad de ser seleccionado.
#
# - **Muestreo Estratificado:** Divide la población en subgrupos (estratos) y luego selecciona muestras de cada estrato.
#
# **Fórmula Matemática para la Media Muestral $(\bar{X})$:**
#
# $\bar{X} = \frac{\sum_{i=1}^{n} X_i}{n}$
#
# Donde:
#
# - $\bar{X}$ es la media muestral.
#
# - $( X_i )$ son los valores individuales en la muestra.
#
# - $( n )$ es el tamaño de la muestra.
#
# **Remuestreo:**
#
# El remuestreo es una técnica que implica tomar repetidamente muestras de un conjunto de datos existente con el propósito de realizar inferencias adicionales sobre la población subyacente.
#
# **Terminología:**
#
# - **Bootstrap:** Un método de remuestreo que implica tomar muestras con reemplazo de la muestra original.
#
# - **Jackknife:** Un método de remuestreo que implica omitir un solo elemento de la muestra original a la vez para crear conjuntos de datos más pequeños.
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de una distribución normal
np.random.seed(42)
population_data = np.random.normal(loc=50, scale=10, size=1000)

# Muestreo aleatorio simple
sample = np.random.choice(population_data, size=100, replace=False)

# Bootstrap (remuestreo con reemplazo)
bootstrap_samples = [np.random.choice(sample, size=len(sample), replace=True) for _ in range(1000)]
bootstrap_means = np.mean(bootstrap_samples, axis=1)

# Personalizar la apariencia de la gráfica
plt.figure(figsize=(16, 6))

# Histograma de la población
plt.subplot(1, 3, 1)
plt.hist(population_data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Población')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)

# Histograma de la muestra
plt.subplot(1, 3, 2)
plt.hist(sample, bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Muestra')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)

# Histograma de las medias bootstrap
plt.subplot(1, 3, 3)
plt.hist(bootstrap_means, bins=30, color='coral', edgecolor='black', alpha=0.7)
plt.title('Bootstrap Means')
plt.xlabel('Valor Medio Bootstrap')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# En este ejemplo:
# - Generamos datos de una distribución normal para representar la población.
# - Realizamos un muestreo aleatorio simple para obtener una muestra.
# - Aplicamos el método bootstrap para generar múltiples muestras (con reemplazo) y calculamos las medias muestrales.
# - Visualizamos la población, la muestra y la distribución de las medias bootstrap.

# %% [markdown]
# | **Inicio** | **atrás 50** | **Siguiente 52** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./50_%20t-test.ipynb)| [⏩](./52_Central_Limit_Theorem.ipynb)|
