# %% [markdown]
# | **Inicio** | **atrás 28** | **Siguiente 30** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./28_Bagging.ipynb)| [⏩](./30_R2_score.ipynb)|

# %% [markdown]
# # **29. Root Mean Square Error**

# %% [markdown]
# El Root Mean Square Error (Error Cuadrático Medio) es una métrica comúnmente utilizada para evaluar la precisión de un modelo de regresión. Mide la diferencia entre los valores predichos por el modelo y los valores reales de la variable dependiente. La raíz cuadrada del error cuadrático medio proporciona una medida de la dispersión de los errores en unidades originales.
#
# **Terminología:**
#
# 1. **Error Cuadrático:** La diferencia al cuadrado entre la predicción del modelo y el valor real.
#
# 2. **Error Cuadrático Medio (MSE):** El promedio de los errores cuadráticos.
#
# 3. **Root Mean Square Error (RMSE):** La raíz cuadrada del MSE. Representa la desviación estándar de los errores.
#
# **Fórmula Matemática:**
#
# La fórmula del RMSE se expresa matemáticamente de la siguiente manera:
#
# $RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(y_i - \hat{y}_i)^2}$
#
# - $( n )$ es el número total de observaciones.
# - $( y_i )$ es el valor real de la observación $( i )$.
# - $\hat{y}_i$ es el valor predicho para la observación $( i )$.
#
# **Interpretación:**
#
# El RMSE cuantifica la magnitud promedio de los errores de predicción. Un RMSE más bajo indica una mejor concordancia entre las predicciones del modelo y los valores reales.
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Datos de ejemplo
y_true = np.array([2, 4, 5, 4, 5])
y_pred = np.array([1.5, 3.5, 4.5, 5, 5.5])

# Calcular el Error Cuadrático Medio (MSE)
mse = mean_squared_error(y_true, y_pred)

# Calcular el RMSE
rmse = np.sqrt(mse)

# Visualizar los datos y las predicciones con líneas de conexión
plt.figure(figsize=(8, 6))
plt.plot(range(len(y_true)), y_true, marker='o', linestyle='-', label='Real', color='blue')
plt.plot(range(len(y_pred)), y_pred, marker='o', linestyle='-', label='Predicción', color='orange')

# Líneas conectando los puntos reales y predichos
for i in range(len(y_true)):
    plt.plot([i, i], [y_true[i], y_pred[i]], color='gray', linestyle='--', linewidth=1)

plt.legend()
plt.xlabel('Observaciones')
plt.ylabel('Valores')
plt.title(f'RMSE: {rmse:.2f}')
plt.show()

# %% [markdown]
# Este ejemplo ilustra cómo calcular el RMSE utilizando la biblioteca scikit-learn en Python. Se comparan los valores reales con las predicciones y se muestra un gráfico que indica visualmente la diferencia entre ellos. La métrica RMSE se calcula para evaluar la calidad del modelo de regresión.

# %% [markdown]
# | **Inicio** | **atrás 28** | **Siguiente 30** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./28_Bagging.ipynb)| [⏩](./30_R2_score.ipynb)|
