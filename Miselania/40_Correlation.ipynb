# %% [markdown]
# | **Inicio** | **atrás 39** | **Siguiente 41** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./39_Agglomerative_Clustering.ipynb)| [⏩](./41_Affinity_Propagation.ipynb)|

# %% [markdown]
# # **40. Correlation**

# %% [markdown]
# **Correlación: Explicación Detallada**
#
# **Introducción:**
#
# La correlación es una medida estadística que describe la relación entre dos variables. Indica cómo los cambios en una variable están asociados con los cambios en otra. La correlación no implica causalidad, pero simplemente cuantifica la fuerza y la dirección de la relación lineal entre dos variables.
#
# **Terminología:**
#
# 1. **Coeficiente de Correlación (r):** Representa la fuerza y dirección de la relación lineal entre dos variables. Varía entre -1 y 1.
#    - **r = 1:** Correlación positiva perfecta.
#    - **r = -1:** Correlación negativa perfecta.
#    - **r ≈ 0:** No hay correlación.
#
# 2. **Matriz de Correlación:** Una tabla que muestra los coeficientes de correlación entre varias variables.
#
# **Fórmula Matemática:**
#
# El coeficiente de correlación (r) se calcula mediante la siguiente fórmula:
# $r = \frac{\sum{(X_i - \bar{X})(Y_i - \bar{Y})}}{\sqrt{\sum{(X_i - \bar{X})^2} \sum{(Y_i - \bar{Y})^2}}}$
#
# Donde:
#
# - $(X_i)$ y $(Y_i)$ son los valores individuales de las dos variables.
# - $(\bar{X})$ y $(\bar{Y})$ son las medias de las dos variables.
#
# **Ejemplo en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
np.random.seed(42)
X = np.random.rand(50)
Y = 2 * X + 1 + 0.1 * np.random.randn(50)  # Relación lineal con ruido

# Calcular el coeficiente de correlación
correlation_coef = np.corrcoef(X, Y)[0, 1]

# Personalizar la apariencia de la gráfica
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, label=f'Correlación = {correlation_coef:.2f}', color='blue', marker='o', edgecolors='black', alpha=0.7)

# Personalizar etiquetas y título
plt.xlabel('Variable X', fontsize=14)
plt.ylabel('Variable Y', fontsize=14)
plt.title('Correlación entre X e Y', fontsize=16)

# Personalizar la leyenda
plt.legend(fontsize=12)

# Mostrar la cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# En este ejemplo, se generan datos con una relación lineal y se visualiza la dispersión de los puntos. El coeficiente de correlación se calcula usando `np.corrcoef`.

# %% [markdown]
# | **Inicio** | **atrás 39** | **Siguiente 41** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./39_Agglomerative_Clustering.ipynb)| [⏩](./41_Affinity_Propagation.ipynb)|
