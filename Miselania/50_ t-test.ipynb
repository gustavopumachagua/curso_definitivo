# %% [markdown]
# | **Inicio** | **atrás 49** | **Siguiente 51** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./49_Poisson_Distribution.ipynb)| [⏩](./51_Sampling_and_Resampling.ipynb)|

# %% [markdown]
# # **50. t-test**

# %% [markdown]
# **Prueba t de Student (t-test): Explicación Detallada**
#
# **Introducción:**
#
# La prueba t de Student, o simplemente t-test, es una técnica estadística utilizada para comparar las medias de dos grupos y determinar si hay una diferencia significativa entre ellas. Es especialmente útil cuando se trabaja con muestras pequeñas y se asume que las poblaciones de las que provienen los grupos son aproximadamente normales.
#
# **Terminología:**
#
# - **Variable Dependiente:** La característica que estamos midiendo en ambos grupos.
#
# - **Variable Independiente:** La característica que define los grupos.
#
# - **Hipótesis Nula $(H_0)$:** Afirma que no hay diferencia significativa entre las medias de los dos grupos.
#
# - **Hipótesis Alternativa $(H_1)$ o $(H_a)$:** Afirma que hay una diferencia significativa entre las medias de los dos grupos.
#
# **Fórmula Matemática:**
#
# La fórmula de la prueba t para muestras independientes es:
#
# $t = \frac{\bar{X}_1 - \bar{X}_2}{\sqrt{\frac{s_1^2}{n_1} + \frac{s_2^2}{n_2}}}$
#
# Donde:
#
# - $(\bar{X}_1)$ y $(\bar{X}_2)$ son las medias de los dos grupos.
#
# - $(s_1)$ y $(s_2)$ son las desviaciones estándar de los dos grupos.
#
# - $(n_1)$ y $(n_2)$ son los tamaños de las muestras de los dos grupos.
#
# **Prueba de dos colas:**
#
# En la prueba de dos colas, se busca si hay una diferencia significativa en ambas direcciones. La región crítica se encuentra en ambos extremos de la distribución t.
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Generar datos para dos grupos
np.random.seed(42)
group1 = np.random.normal(loc=5, scale=2, size=30)
group2 = np.random.normal(loc=7, scale=2, size=30)

# Realizar la prueba t de dos colas
t_statistic, p_value = stats.ttest_ind(group1, group2)

# Personalizar la apariencia de la gráfica
plt.figure(figsize=(10, 6))

# Histograma para el Grupo 1
plt.hist(group1, alpha=0.5, label='Grupo 1', color='blue', edgecolor='black', bins=15)

# Histograma para el Grupo 2
plt.hist(group2, alpha=0.5, label='Grupo 2', color='orange', edgecolor='black', bins=15)

# Personalizar etiquetas y título
plt.title('Distribuciones de los Dos Grupos', fontsize=16)
plt.xlabel('Valores', fontsize=14)
plt.ylabel('Frecuencia', fontsize=14)

# Añadir leyenda
plt.legend(fontsize=12)

# Mostrar cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Añadir línea vertical para la prueba t
plt.axvline(x=np.mean(group1), color='blue', linestyle='--', linewidth=2, label='Media Grupo 1')
plt.axvline(x=np.mean(group2), color='orange', linestyle='--', linewidth=2, label='Media Grupo 2')

# Imprimir el resultado de la prueba t
print(f'Test Statistic: {t_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Interpretar el resultado
if p_value < 0.05:
    plt.text(9, 5, 'Diferencia significativa', fontsize=12, color='red')
else:
    plt.text(9, 5, 'No hay diferencia significativa', fontsize=12, color='green')

# Mostrar la gráfica
plt.show()
# Out:
# Test Statistic: -4.5129
# P-value: 0.0000

# %% [markdown]
# Este ejemplo utiliza la biblioteca `scipy.stats` para realizar una prueba t de dos colas entre dos grupos generados aleatoriamente. La prueba t se realiza para determinar si hay una diferencia significativa entre las medias de los dos grupos. El resultado de la prueba y las distribuciones de los grupos se muestran en un gráfico.

# %% [markdown]
# | **Inicio** | **atrás 49** | **Siguiente 51** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./49_Poisson_Distribution.ipynb)| [⏩](./51_Sampling_and_Resampling.ipynb)|
