# %% [markdown]
# | **Inicio** | **atrás 33** | **Siguiente 35** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./33_Underfitting_and_Overfitting.ipynb)| [⏩](./35_Hierarchical_Clustering.ipynb)|

# %% [markdown]
# # **34. Data normalization**

# %% [markdown]
# **Terminología:**
#
# La normalización de datos, también conocida como escalamiento, es un paso común en el preprocesamiento de datos en machine learning. Su objetivo es ajustar los valores de las características para que estén dentro de un rango específico, lo que puede mejorar el rendimiento de ciertos algoritmos y facilitar la convergencia del modelo.
#
# **Métodos Comunes de Normalización:**
#
# 1. **Min-Max Scaling:**
#
#    $X_{\text{norm}} = \frac{X - X_{\text{min}}}{X_{\text{max}} - X_{\text{min}}}$
#
#    **Donde:**
#
#    - $(X)$ es el valor original.
#    - $(X_{\text{min}})$ es el valor mínimo en la característica.
#    - $(X_{\text{max}})$ es el valor máximo en la característica.
#
# 2. **Z-Score Normalization (Standardization):**
#
#    $X_{\text{norm}} = \frac{X - \mu}{\sigma}$
#
#    **Donde:**
#
#    - $(X)$ es el valor original.
#    - $(\mu)$ es la media de la característica.
#    - $(\sigma)$ es la desviación estándar de la característica.
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
data = np.array([1, 5, 10, 20, 50, 100], dtype=float)

# Min-Max Scaling
min_max_scaled = (data - np.min(data)) / (np.max(data) - np.min(data))

# Z-Score Normalization
z_score_normalized = (data - np.mean(data)) / np.std(data)

# Personalizar la apariencia de la gráfica
plt.figure(figsize=(12, 4))

# Gráfica de datos originales
plt.subplot(1, 3, 1)
plt.plot(data, marker='o', linestyle='-', color='b')
plt.title('Datos Originales')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.grid(True, linestyle='--', alpha=0.7)

# Gráfica de Min-Max Scaling
plt.subplot(1, 3, 2)
plt.plot(min_max_scaled, marker='o', linestyle='-', color='r')
plt.title('Min-Max Scaling')
plt.xlabel('Índice')
plt.ylabel('Valor Normalizado [0, 1]')
plt.grid(True, linestyle='--', alpha=0.7)

# Gráfica de Z-Score Normalization
plt.subplot(1, 3, 3)
plt.plot(z_score_normalized, marker='o', linestyle='-', color='g')
plt.title('Z-Score Normalization')
plt.xlabel('Índice')
plt.ylabel('Valor Normalizado (Z-Score)')
plt.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño de las subgráficas
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se utiliza Min-Max Scaling y Z-Score Normalization para normalizar un conjunto de datos. El gráfico muestra la distribución de los datos originales y cómo cambian después de aplicar cada método de normalización.

# %% [markdown]
# | **Inicio** | **atrás 33** | **Siguiente 35** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./33_Underfitting_and_Overfitting.ipynb)| [⏩](./35_Hierarchical_Clustering.ipynb)|
