# %% [markdown]
# | **Inicio** | **atrás 45** | **Siguiente 47** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./45.Logistic_Regression.ipynb)| [⏩](./47_TF-IDF.ipynb)|

# %% [markdown]
# # **46. Binomial Distribution**

# %% [markdown]
# **Distribución Binomial: Explicación Detallada**
#
# **Terminología:**
#
# - **Ensayo Bernoulli:** Es un experimento con dos resultados posibles, generalmente denominados éxito y fracaso.
# - **Número de Ensayos $(n)$:** Representa la cantidad total de ensayos en una secuencia de ensayos Bernoulli.
# - **Probabilidad de Éxito $(p)$:** Es la probabilidad de que ocurra un éxito en un solo ensayo Bernoulli.
# - **Variable Aleatoria Binomial $(X)$:** Representa el número total de éxitos en una secuencia de $(n)$ ensayos Bernoulli.
#
# **Fórmula Matemática:**
#
# La función de masa de probabilidad (PMF) de la distribución binomial se define como:
#
# $P(X = k) = \binom{n}{k} \cdot p^k \cdot (1 - p)^{n - k}$
#
# Donde:
#
# - $P(X = k)$ es la probabilidad de tener $(k)$ éxitos en $(n)$ ensayos.
# - $\binom{n}{k}$ es el coeficiente binomial, que representa el número de formas de elegir $(k)$ éxitos de $(n)$ ensayos.
# - $( p )$ es la probabilidad de éxito en un solo ensayo.
# - $( k )$ es el número de éxitos deseados.
# - $( n )$ es el número total de ensayos.
#
# **Ejemplo con Código Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parámetros de la distribución binomial
n = 10  # Número de ensayos
p = 0.5  # Probabilidad de éxito en un solo ensayo

# Crear una secuencia de valores para la variable aleatoria binomial
k_values = np.arange(0, n+1)

# Calcular las probabilidades para cada valor de k
probabilities = binom.pmf(k_values, n, p)

# Visualizar la distribución binomial
plt.bar(k_values, probabilities, align='center', alpha=0.7, color='blue', edgecolor='k')
plt.title('Distribución Binomial')
plt.xlabel('Número de Éxitos (k)')
plt.ylabel('Probabilidad')
plt.show()

# %% [markdown]
# Este código utiliza la función de masa de probabilidad (PMF) de la distribución binomial para visualizar la probabilidad de cada número de éxitos $(k)$ en una secuencia de $(n)$ ensayos Bernoulli. El gráfico resultante es una distribución binomial.

# %% [markdown]
# | **Inicio** | **atrás 45** | **Siguiente 47** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./45.Logistic_Regression.ipynb)| [⏩](./47_TF-IDF.ipynb)|
