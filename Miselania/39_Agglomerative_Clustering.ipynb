# %% [markdown]
# | **Inicio** | **atrás 38** | **Siguiente 40** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./38_Mean_Shift.ipynb)| [⏩](./40_Correlation.ipynb)|

# %% [markdown]
# # **39. Agglomerative Clustering**

# %% [markdown]
# **Agglomerative Clustering: Explicación Detallada**
#
# **Introducción:**
#
# El Agglomerative Clustering es un algoritmo de agrupamiento jerárquico que construye una jerarquía de grupos. Este enfoque comienza considerando cada punto de datos como un clúster individual y luego fusiona gradualmente los clústeres más cercanos para formar grupos más grandes. Este proceso se repite hasta que todos los puntos de datos están en un solo clúster o hasta que se cumple un criterio predefinido.
#
# **Terminología:**
#
# 1. **Matriz de Enlace (Linkage Matrix):** Matriz que registra las fusiones de clústeres y las distancias entre ellos en cada paso.
#
# 2. **Enlace (Linkage):** Criterio utilizado para medir la distancia entre dos clústeres y decidir cuáles fusionar. Algunos métodos comunes son el enlace único, enlace completo y enlace promedio.
#
# 3. **Dendrograma:** Representación gráfica de la jerarquía de clústeres que muestra cómo los clústeres se fusionan a lo largo del tiempo.
#
# **Fórmula Matemática:**
#
# La fórmula matemática específica puede variar según el método de enlace seleccionado. La distancia entre dos clústeres se mide en función de la proximidad entre sus puntos de datos. Por ejemplo, en el enlace único, la distancia entre dos clústeres se define como la distancia más corta entre cualquier par de puntos de los dos clústeres.
#
# **Ejemplo en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Generar datos de ejemplo
np.random.seed(42)
X = np.random.rand(10, 2)

# Calcular la matriz de enlace utilizando enlace completo
Z = linkage(X, method='complete')

# Crear el dendrograma
dendrogram(Z)

# Mostrar el dendrograma
plt.title('Dendrograma')
plt.xlabel('Índice de Datos')
plt.ylabel('Distancia')
plt.show()

# %% [markdown]
# Este ejemplo genera datos aleatorios bidimensionales y utiliza el método de enlace completo para construir un dendrograma que muestra la jerarquía de agrupamiento. Puedes ajustar el método de enlace y otros parámetros según tus necesidades específicas.

# %% [markdown]
# | **Inicio** | **atrás 38** | **Siguiente 40** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./38_Mean_Shift.ipynb)| [⏩](./40_Correlation.ipynb)|
