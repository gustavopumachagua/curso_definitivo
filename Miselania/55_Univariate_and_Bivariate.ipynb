# %% [markdown]
# | **Inicio** | **atrás 54** |
# |----------- |-------------- |
# | [🏠](../README.md) | [⏪](./54_Chi-Square.ipynb)|

# %% [markdown]
# # **55. Univariate and Bivariate**

# %% [markdown]
# **Análisis Univariado y Bivariado: Explicación Detallada**
#
# **Análisis Univariado:**
#
# - **Definición:** El análisis univariado se centra en el estudio de una sola variable a la vez. Examina las propiedades, distribuciones y características de una única variable sin considerar la relación con otras variables.
#
# - **Terminología:**
#
#   - **Variable:** Una característica o propiedad que puede variar. En el análisis univariado, se estudia una variable a la vez.
#   - **Estadísticas Descriptivas:** Métricas que resumen y describen las propiedades de una variable, como la media, la mediana, la desviación estándar, etc.
#   - **Histograma:** Gráfico que muestra la distribución de una variable a través de barras.
#
# **Ejemplo de Análisis Univariado en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
data = np.random.randn(1000)

# Personalizar el histograma
plt.figure(figsize=(8, 6))

# Histograma con bordes más oscuros
plt.hist(data, bins=30, color='blue', edgecolor='black', alpha=0.7)

# Añadir una línea vertical para la media
mean_value = np.mean(data)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Media = {mean_value:.2f}')

# Añadir una línea vertical para la mediana
median_value = np.median(data)
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label=f'Mediana = {median_value:.2f}')

# Añadir una leyenda
plt.legend()

# Añadir etiquetas y título
plt.title('Histograma: Análisis Univariado')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')

# Mostrar la cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Ajustar el diseño
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se genera un conjunto de datos aleatorios y se visualiza su distribución mediante un histograma. Esto es un análisis univariado, ya que estamos examinando las propiedades de una sola variable.
#
# **Análisis Bivariado:**
#
# - **Definición:** El análisis bivariado implica el estudio de dos variables simultáneamente para examinar la relación entre ellas. Busca comprender cómo cambia una variable cuando la otra varía.
#
# - **Terminología:**
#
#   - **Variables Bivariadas:** Dos variables que se estudian en conjunto.
#   - **Diagrama de Dispersión:** Gráfico que representa puntos en un plano cartesiano, donde cada punto corresponde a los valores de ambas variables.
#   - **Correlación:** Medida estadística que cuantifica la relación lineal entre dos variables.
#
# **Ejemplo de Análisis Bivariado en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
x = np.random.randn(100)
y = 2 * x + np.random.randn(100)

# Personalizar el diagrama de dispersión
plt.figure(figsize=(8, 6))

# Diagrama de dispersión con puntos más grandes y color más claro
plt.scatter(x, y, color='skyblue', alpha=0.7, s=50)

# Añadir una línea de regresión
plt.plot(x, 2 * x, color='red', linestyle='dashed', linewidth=2, label='Regresión Lineal')

# Añadir etiquetas para los ejes y título
plt.title('Diagrama de Dispersión: Análisis Bivariado')
plt.xlabel('Variable X')
plt.ylabel('Variable Y')

# Añadir una leyenda
plt.legend()

# Mostrar la cuadrícula
plt.grid(True, linestyle='--', alpha=0.5)

# Ajustar el diseño
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# En este ejemplo, se generan dos conjuntos de datos y se visualizan en un diagrama de dispersión. La relación lineal entre las dos variables se evidencia en el análisis bivariado.
#
# **Resumen:**
#
# - El análisis univariado se centra en una variable a la vez, mientras que el análisis bivariado examina la relación entre dos variables.
# - En el análisis univariado, se utilizan estadísticas descriptivas y gráficos como histogramas.
# - En el análisis bivariado, se emplean diagramas de dispersión y medidas de correlación para entender la relación entre dos variables.

# %% [markdown]
# | **Inicio** | **atrás 54** |
# |----------- |-------------- |
# | [🏠](../README.md) | [⏪](./54_Chi-Square.ipynb)|
