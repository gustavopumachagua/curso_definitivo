# %% [markdown]
# | **Inicio** | **atrás 35** | **Siguiente 37** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./35_Hierarchical_Clustering.ipynb)| [⏩](./37_Distributions.ipynb)|

# %% [markdown]
# # **36. DBSCAN algorithm**

# %% [markdown]
# **DBSCAN (Density-Based Spatial Clustering of Applications with Noise):**
#
# **Explicación:**
#
# DBSCAN es un algoritmo de agrupamiento basado en la densidad que divide el conjunto de datos en clusters basándose en la densidad de los puntos. A diferencia de los métodos de agrupamiento basados en la distancia, DBSCAN no requiere especificar el número de clusters de antemano y puede identificar clusters de formas arbitrarias.
#
# **Terminología:**
#
# 1. **Épsilon (ε):** Es el parámetro que especifica la distancia máxima entre dos puntos para que uno sea considerado en el vecindario del otro.
#
# 2. **MinPts:** Es el número mínimo de puntos requeridos para formar un cluster. Un punto se considera parte de un cluster si hay al menos MinPts puntos dentro de una distancia ε de él.
#
# 3. **Core Points:** Son los puntos que tienen al menos MinPts puntos dentro de ε de su vecindario.
#
# 4. **Border Points:** Son puntos que tienen menos de MinPts puntos en su vecindario pero están dentro de ε de un Core Point.
#
# 5. **Noise (Outliers):** Son puntos que no son Core Points ni Border Points.
#
# **Fórmula Matemática:**
#
# El algoritmo DBSCAN no tiene una fórmula matemática única, pero la clasificación de puntos como Core, Border o Noise se basa en la definición del vecindario ε de cada punto.
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# Generar datos de ejemplo (dos lunas)
data, _ = make_moons(n_samples=200, noise=0.05, random_state=42)

# Aplicar DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(data)

# Personalizar la apariencia de la gráfica
plt.figure(figsize=(8, 6))
scatter = plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', edgecolors='k', marker='o')

# Agregar leyenda para los puntos ruidosos (-1)
legend_labels = list(set(labels) - {-1})
legend_labels.append(-1)
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=scatter.cmap(scatter.norm(label)), markersize=10) for label in legend_labels]
plt.legend(legend_handles, legend_labels, title='Etiquetas de Cluster')

# Personalizar etiquetas y título
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('DBSCAN: Detección de Clusters')

plt.show()

# %% [markdown]
# En este ejemplo, se generan datos en forma de dos lunas, y DBSCAN se aplica para detectar los clusters. El parámetro ε y MinPts se ajustan según la densidad esperada de los clusters.

# %% [markdown]
# | **Inicio** | **atrás 35** | **Siguiente 37** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./35_Hierarchical_Clustering.ipynb)| [⏩](./37_Distributions.ipynb)|
