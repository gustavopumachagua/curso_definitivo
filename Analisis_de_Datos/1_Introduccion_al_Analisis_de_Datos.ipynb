# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../README.md)|  [⏩](./2_Fundamentos_de_Programacion.ipynb)|

# %% [markdown]
# # **1. Introducción al Análisis de Datos**

# %% [markdown]
# ## **Definiciones y Conceptos Básicos**

# %% [markdown]
# ### **¿Qué es el análisis de datos?**

# %% [markdown]
# **Análisis de Datos:**
#
# El análisis de datos es el proceso de inspeccionar, limpiar, transformar y modelar datos con el objetivo de descubrir información útil, llegar a conclusiones y apoyar la toma de decisiones. Este proceso puede incluir diversas técnicas y enfoques, desde estadísticas descriptivas hasta técnicas más avanzadas de minería de datos y aprendizaje automático.
#
# **Pasos Comunes en el Análisis de Datos:**
#
# 1. **Recopilación de Datos:**
#
#    - Obtener datos de diversas fuentes, como bases de datos, archivos CSV, APIs, etc.
#
# 2. **Exploración y Limpiado de Datos:**
#
#    - Explorar los datos para entender su estructura.
#    - Identificar y tratar valores atípicos o datos faltantes.
#    - Realizar transformaciones necesarias.
#
# 3. **Análisis Descriptivo:**
#
#    - Calcular estadísticas descriptivas como la media, la mediana, la desviación estándar, etc.
#    - Crear visualizaciones para entender la distribución de los datos.
#
# 4. **Análisis Exploratorio de Datos (EDA):**
#
#    - Utilizar técnicas visuales y estadísticas para explorar las relaciones entre variables.
#    - Identificar patrones, tendencias y posibles correlaciones.
#
# 5. **Modelado y Predicción:**
#
#    - Aplicar técnicas de modelado estadístico o aprendizaje automático para hacer predicciones o tomar decisiones basadas en los datos.
#
# 6. **Comunicación de Resultados:**
#
#    - Presentar los resultados de manera clara y comprensible para audiencias no técnicas.
#
# **Ejemplo Práctico en Python con Gráficos:**
#
# Vamos a utilizar un conjunto de datos simple y realizar un análisis exploratorio básico con Python y la biblioteca `matplotlib`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un conjunto de datos ficticio
datos = {
    'Edad': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
    'Ingresos': [50000, 60000, 75000, 90000, 110000, 100000, 95000, 85000, 80000, 70000],
    'Gasto_Mensual': [2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]
}

df = pd.DataFrame(datos)

# Visualizar la relación entre Edad e Ingresos
plt.scatter(df['Edad'], df['Ingresos'])
plt.title('Relación entre Edad e Ingresos')
plt.xlabel('Edad')
plt.ylabel('Ingresos')
plt.show()

# Visualizar la distribución de Gasto Mensual
plt.hist(df['Gasto_Mensual'], bins=5, edgecolor='black')
plt.title('Distribución de Gasto Mensual')
plt.xlabel('Gasto Mensual')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# En este ejemplo:
#
# - Creamos un DataFrame de pandas con datos ficticios sobre edad, ingresos y gasto mensual.
# - Utilizamos un gráfico de dispersión para visualizar la relación entre edad e ingresos.
# - Utilizamos un histograma para visualizar la distribución del gasto mensual.
#
# Este es un análisis exploratorio de datos simple, pero muestra cómo se pueden utilizar visualizaciones para entender mejor los datos y las relaciones entre variables. En un escenario real, se realizarían análisis más profundos y se aplicarían técnicas estadísticas y de modelado según las necesidades específicas del problema.

# %% [markdown]
# ### **Importancia y aplicaciones en diferentes sectores**

# %% [markdown]
# El análisis de datos es esencial en diversos sectores y desempeña un papel crucial en la toma de decisiones informadas, la mejora de procesos y la identificación de oportunidades. A continuación, se destacan la importancia y algunas aplicaciones en distintos sectores, junto con ejemplos y gráficos personalizados en código Python.
#
# 1. **Sector Empresarial:**
#
#    - **Importancia:**
#
#      - Optimización de operaciones.
#      - Identificación de oportunidades de crecimiento.
#
#    - **Aplicaciones:**
#
#      - Análisis de ventas para identificar productos más vendidos.
#      - Pronóstico de demanda para la gestión de inventario.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame de ventas
datos_ventas = {
    'Fecha': pd.date_range('2022-01-01', '2022-12-31', freq='M'),  # Usar frecuencia mensual
    'Ventas': [200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750]
}

df_ventas = pd.DataFrame(datos_ventas)

# Visualizar las ventas a lo largo del tiempo
plt.plot(df_ventas['Fecha'], df_ventas['Ventas'], marker='o')
plt.title('Ventas Mensuales')
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# 2. **Salud:**
#
#    - **Importancia:**
#
#      - Mejora en la atención al paciente.
#      - Identificación de patrones de enfermedades.
#    - **Aplicaciones:**
#
#      - Análisis de datos médicos para predecir enfermedades.
#      - Monitoreo de la eficacia de tratamientos.

# %%
import seaborn as sns
from sklearn.datasets import load_iris

# Cargar el conjunto de datos de Iris
iris = load_iris()
df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['Species'] = iris.target_names[iris.target]

# Visualizar relaciones entre características en un gráfico de dispersión
sns.pairplot(df_iris, hue='Species')

plt.show()
# Out:
# /home/puma/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 3. **Finanzas:**
#
#    - **Importancia:**
#
#      - Evaluación del rendimiento financiero.
#      - Gestión de riesgos.
#
#    - **Aplicaciones:**
#
#      - Análisis de rendimiento de inversiones.
#      - Detección de fraudes mediante patrones anómalos.

# %%
import yfinance as yf

# Descargar datos históricos de precios de acciones
datos_acciones = yf.download('AAPL', start='2022-01-01', end='2023-01-01')

# Visualizar el rendimiento de las acciones
datos_acciones['Adj Close'].plot(title='Precio de Cierre Ajustado de AAPL')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Ajustado')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 4. **Educación:**
#
#    - **Importancia:**
#
#      - Mejora en la eficacia de la enseñanza.
#      - Personalización del aprendizaje.
#
#    - **Aplicaciones:**
#
#      - Análisis de datos de estudiantes para identificar áreas de mejora.
#      - Predicción del rendimiento académico.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame de calificaciones de estudiantes
datos_calificaciones = {
       'Estudiante': ['Estudiante1', 'Estudiante2', 'Estudiante3', 'Estudiante4'],
       'Calificación': [85, 90, 78, 92]
   }

df_calificaciones = pd.DataFrame(datos_calificaciones)
   
# Visualizar las calificaciones de los estudiantes
plt.bar(df_calificaciones['Estudiante'], df_calificaciones['Calificación'])
plt.title('Calificaciones de Estudiantes')
plt.xlabel('Estudiante')
plt.ylabel('Calificación')
plt.show()

# %% [markdown]
# 5. **Marketing:**
#
#    - **Importancia:**
#
#      - Segmentación de clientes.
#      - Evaluación de campañas de marketing.
#
#    - **Aplicaciones:**
#
#      - Análisis de datos de clientes para personalizar estrategias de marketing.
#      - Medición del retorno de inversión (ROI) de campañas publicitarias.

# %%
import pandas as pd
import seaborn as sns

# Crear un DataFrame de datos de clientes
datos_clientes = {
       'Edad': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
       'Gasto_Anual': [2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]
   }

df_clientes = pd.DataFrame(datos_clientes)
   
# Visualizar la relación entre Edad y Gasto Anual
sns.scatterplot(x='Edad', y='Gasto_Anual', data=df_clientes)
plt.title('Relación entre Edad y Gasto Anual')
plt.xlabel('Edad')
plt.ylabel('Gasto Anual')
plt.show()

# %% [markdown]
# Estos son solo ejemplos representativos, y el análisis de datos se aplica en una variedad de sectores para resolver problemas específicos y tomar decisiones fundamentadas. Las bibliotecas como pandas, matplotlib y seaborn en Python son herramientas comunes utilizadas en este proceso.

# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../README.md)|  [⏩](./2_Fundamentos_de_Programacion.ipynb)|
