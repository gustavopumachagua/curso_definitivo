# %% [markdown]
# | **Inicio** | **atrás 2** | **Siguiente 4** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./2_Estadisticas_y_Probabilidades.ipynb)| [⏩](./4_Algebra_Lineal_Avanzada.ipynb)|

# %% [markdown]
# # **3. Cálculo Multivariable**

# %% [markdown]
# ## **Derivadas Parciales**

# %% [markdown]
# ### **Derivadas parciales de funciones multivariables**

# %% [markdown]
# Las derivadas parciales son un concepto fundamental en cálculo y análisis matemático, especialmente cuando se trabaja con funciones de varias variables. Mientras que la derivada de una función de una variable mide la tasa de cambio con respecto a una variable, las derivadas parciales miden la tasa de cambio con respecto a una variable específica, manteniendo las otras variables constantes.
#
# **Fórmula Matemática:**
#
# Supongamos que tenemos una función $f(x, y)$ de dos variables. La derivada parcial de $(f)$ con respecto a $(x)$ se denota como $\frac{\partial f}{\partial x}$ y se calcula manteniendo $(y)$ constante:
#
# $\frac{\partial f}{\partial x} = \lim_{h \to 0} \frac{f(x + h, y) - f(x, y)}{h}$
#
# Análogamente, la derivada parcial de $(f)$ con respecto a $(y)$ se denota como $\frac{\partial f}{\partial y}$ y se calcula manteniendo $(x)$ constante:
#
# $\frac{\partial f}{\partial y} = \lim_{h \to 0} \frac{f(x, y + h) - f(x, y)}{h}$
#
# **Ejemplo con Gráfico en Python:**
#
# Vamos a considerar la función $f(x, y) = x^2 + 2y^2$ y calcular sus derivadas parciales con respecto a $(x)$ e $(y)$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función
def f(x, y):
    return x**2 + 2*y**2

# Calcular las derivadas parciales
def df_dx(x, y, h=1e-5):
    return (f(x + h, y) - f(x, y)) / h

def df_dy(x, y, h=1e-5):
    return (f(x, y + h) - f(x, y)) / h

# Generar datos para el gráfico
x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Calcular las derivadas parciales en un punto específico
x_point = 2
y_point = 1
df_dx_point = df_dx(x_point, y_point)
df_dy_point = df_dy(x_point, y_point)

# Graficar la función y las derivadas parciales
fig = plt.figure(figsize=(12, 5))

# Gráfico de la función
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(X, Y, Z, cmap='viridis')
ax1.set_title('Función $f(x, y) = x^2 + 2y^2$')

# Gráfico de las derivadas parciales en el punto específico
ax2 = fig.add_subplot(122)
ax2.quiver(x_point, y_point, df_dx_point, df_dy_point, scale=100, color='red', label='Derivadas Parciales')
ax2.set_title('Derivadas Parciales en el Punto Específico')
ax2.contour(X, Y, Z, levels=20, cmap='viridis', alpha=0.5)
ax2.legend()

plt.show()

# %% [markdown]
# En este ejemplo, calculamos las derivadas parciales de la función $f(x, y) = x^2 + 2y^2$ con respecto a $(x)$ e $(y)$. Luego, graficamos la función tridimensional y las derivadas parciales en un punto específico en el plano $(xy)$. Los vectores rojos en el gráfico de flechas indican las direcciones y magnitudes de las derivadas parciales en ese punto.

# %% [markdown]
# ## **Integrales Múltiples**

# %% [markdown]
# ### **Integrales dobles y triples**

# %% [markdown]
# Las integrales dobles y triples son extensiones de la integración de una variable a funciones de dos y tres variables, respectivamente. Estas herramientas son fundamentales en cálculo y análisis matemático, y se utilizan para calcular áreas, volúmenes, masas y otros conceptos en diversas disciplinas.
#
# **Integral Doble:**
#
# **Fórmula Matemática:**
#
# Para una función $f(x, y)$ sobre una región $(R)$ en el plano $(xy)$, la integral doble se expresa como:
#
# $\iint_R f(x, y) \,dx\,dy$
#
# Donde $(dx\,dy)$ indica la integración respecto a $(x)$ y luego respecto a $(y)$. La región $(R)$ define los límites de integración.
#
# **Ejemplo con Gráfico en Python:**
#
# Vamos a calcular la integral doble de $f(x, y) = x^2 + y^2$ sobre el rectángulo $R = [0, 2] \times [0, 1]$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import dblquad

# Definir la función
def f(x, y):
    return x**2 + y**2

# Definir los límites de integración
x_min, x_max = 0, 2
y_min, y_max = 0, 1

# Calcular la integral doble
result, error = dblquad(f, x_min, x_max, y_min, y_max)

# Imprimir el resultado
print(f"Resultado de la integral doble: {result}")

# Graficar la región R y la función
x_vals = np.linspace(x_min, x_max, 100)
y_vals = np.linspace(y_min, y_max, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

plt.contourf(X, Y, Z, levels=20, cmap='viridis')
plt.colorbar()
plt.title('Región de Integración y Función $f(x, y) = x^2 + y^2$')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Resultado de la integral doble: 3.3333333333333335

# %% [markdown]
# En este ejemplo, calculamos la integral doble de $f(x, y) = x^2 + y^2$ sobre el rectángulo $R = [0, 2] \times [0, 1]$. El gráfico muestra la región de integración y la función.
#
# **Integral Triple:**
#
# **Fórmula Matemática:**
#
# Para una función $g(x, y, z)$ sobre un sólido $(S)$ en el espacio tridimensional, la integral triple se expresa como:
#
# $\iiint_S g(x, y, z) \,dx\,dy\,dz$
#
# Donde $(dx\,dy\,dz)$ indica la integración respecto a $(x)$, $(y)$, y luego respecto a $(z)$. El sólido $(S)$ define los límites de integración.
#
# **Ejemplo con Gráfico en Python:**
#
# Vamos a calcular la integral triple de $g(x, y, z) = xyz$ sobre el cubo $S = [0, 1] \times [0, 1] \times [0, 1]$.

# %%
from scipy.integrate import tplquad

# Definir la función
def g(x, y, z):
    return x * y * z

# Definir los límites de integración
x_min, x_max = 0, 1
y_min, y_max = 0, 1
z_min, z_max = 0, 1

# Calcular la integral triple
result, error = tplquad(g, x_min, x_max, y_min, y_max, z_min, z_max)

# Imprimir el resultado
print(f"Resultado de la integral triple: {result}")
# Out:
# Resultado de la integral triple: 0.12499999999999999

# %% [markdown]
# En este ejemplo, calculamos la integral triple de $g(x, y, z) = xyz$ sobre el cubo $S = [0, 1] \times [0, 1] \times [0, 1]$. No se proporciona un gráfico en este caso debido a la complejidad de representar un sólido tridimensional.
#
# Estos son ejemplos básicos para ilustrar las integrales dobles y triples. Las aplicaciones en ciencia, ingeniería y otras disciplinas son numerosas, ya que estas integrales permiten calcular propiedades físicas y geométricas de objetos en múltiples dimensiones.

# %% [markdown]
# ### **Coordenadas polares y esféricas**

# %% [markdown]
# Las coordenadas polares y esféricas son sistemas alternativos para describir posiciones en el plano y en el espacio tridimensional, respectivamente. Mientras que las coordenadas cartesianas utilizan ejes rectangulares (x, y, z), las coordenadas polares y esféricas utilizan conceptos radiales y angulares.
#
# **Coordenadas Polares:**
#
# En el plano, las coordenadas polares $(r, \theta)$ se definen por la distancia radial $(r)$ desde el origen y el ángulo polar $(\theta)$ entre la línea que conecta el punto con el origen y el eje x.
#
# **Fórmulas Matemáticas:**
#
# $x = r \cdot \cos(\theta)$
#
# $y = r \cdot \sin(\theta)$
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir coordenadas polares
r = 2
theta = np.pi / 4  # 45 grados

# Convertir a coordenadas cartesianas
x = r * np.cos(theta)
y = r * np.sin(theta)

# Graficar punto en coordenadas polares
plt.polar(theta, r, 'ro')  # Gráfico polar
plt.text(theta, r, f'  ({x}, {y})', color='red')
plt.title('Coordenadas Polares')
plt.show()

# %% [markdown]
# En este ejemplo, se define un punto en coordenadas polares $(r, \theta) = (2, \frac{\pi}{4})$ y se convierte a coordenadas cartesianas para graficar el punto en un sistema polar.
#
# **Coordenadas Esféricas:**
#
# En el espacio tridimensional, las coordenadas esféricas $(r, \theta, \phi)$ se definen por la distancia radial $(r)$ desde el origen, el ángulo polar $(\theta)$ (como en coordenadas polares) y el ángulo azimutal $(\phi)$ que mide la inclinación desde el eje z.
#
# **Fórmulas Matemáticas:**
#
# $x = r \cdot \sin(\phi) \cdot \cos(\theta)$
#
# $y = r \cdot \sin(\phi) \cdot \sin(\theta)$
#
# $z = r \cdot \cos(\phi)$
#
# **Ejemplo con Gráfico en Python:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir coordenadas esféricas
r = 2
theta = np.pi / 4  # Ángulo polar
phi = np.pi / 3    # Ángulo azimutal

# Convertir a coordenadas cartesianas
x = r * np.sin(phi) * np.cos(theta)
y = r * np.sin(phi) * np.sin(theta)
z = r * np.cos(phi)

# Graficar punto en coordenadas esféricas
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, color='red', s=100, label=f'({x}, {y}, {z})')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.title('Coordenadas Esféricas')
plt.show()

# %% [markdown]
# En este ejemplo, se define un punto en coordenadas esféricas $(r, \theta, \phi) = (2, \frac{\pi}{4}, \frac{\pi}{3})$ y se convierte a coordenadas cartesianas para graficar el punto en un sistema tridimensional.

# %% [markdown]
# | **Inicio** | **atrás 2** | **Siguiente 4** |
# |----------- |-------------- |---------------|
# | [🏠](../README.md) | [⏪](./2_Estadisticas_y_Probabilidades.ipynb)| [⏩](./4_Algebra_Lineal_Avanzada.ipynb)|
